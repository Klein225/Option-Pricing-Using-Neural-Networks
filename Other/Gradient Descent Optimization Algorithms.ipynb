# %% [markdown]
# # Gradient Descent Optimization Algorithms

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
#pip install tensorflow-addons

# %%
import pandas as pd
import datetime, os
import numpy as np
import numpy.random as npr
from pylab import plt, mpl
import time

from scipy.stats import norm
from scipy import optimize
import scipy.integrate as integrate
import scipy.special as special 

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorboard.plugins.hparams import api as hp
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

import tensorflow_addons as tfa

import matplotlib.pyplot as plt
import seaborn as sns

from keras import backend as BK

# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Lets read the CSV so we dont need to run it again, but can just load it when needed.

# %%
#To read the import the csv-file, use:
raw_Options_input = pd.read_csv (r"/Users/Marcklein/Desktop/Master Thesis/Option pricing using Neural Networks/Python/Heston/Options_input.csv")
raw_Options_output = pd.read_csv (r"/Users/Marcklein/Desktop/Master Thesis/Option pricing using Neural Networks/Python/Heston/Options_output.csv")

#Creates some unnamed column in the beginning, delete it:
del raw_Options_input['Unnamed: 0']
del raw_Options_output['Unnamed: 0']

# %% [markdown]
# We train on the first 5k input/output parameters to speed up the process

# %%
raw_Options_inputz = raw_Options_input[:5000]
raw_Options_outputz = raw_Options_output[:5000]

# %%
Options_input = raw_Options_input.copy()
Options_output = raw_Options_output.copy()

# %% [markdown]
# Since the standard deviation is calculated by taking the sum of the squared deviations from the mean, a zero standard deviation can only be possible when all the values of a variable are the same (all equal to the mean). In this case, those variables have no discriminative power so they can be removed from the analysis. They cannot improve any classification, clustering or regression task. Many implementations will do it for you or throw an error about a matrix calculation.

# %% [markdown]
# ### **Data preparation**
#
# We split our dataset into a training set and a test set (validation set is taken from the training set during model.fit).

# %%
# 90% for training and validating
train_dataset = Options_input.sample(frac=0.9, random_state=42)
test_dataset = Options_input.drop(train_dataset.index)

train_labels = Options_output.sample(frac=0.9, random_state=42)
test_labels = Options_output.drop(train_labels.index)

# %% [markdown]
# Check the overall statistics

# %%
train_stats = train_dataset.describe().T

# %%
#normalize the data
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset).values
normed_test_data = norm(test_dataset).values

#make the labels into numpy array just like the normed training data
train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)

#check the shapes
print("Input train data:", normed_train_data.shape, " Output train data:", train_labels.shape)
print("Input test data:", normed_test_data.shape, " Output test data:", test_labels.shape)
# Out:
# Input train data: (90000, 7)  Output train data: (90000, 10)
# Input test data: (10000, 7)  Output test data: (10000, 10)

# %% [markdown]
# ## **Gradient Descent optimization algorithms**
#
# We look at the following gradient descent optimization algorithms:
# - Momentum optimization
# - Nesterov Accelerated Gradient
# - AdaGrad
# - RMSProp
# - Adam

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
#Create all the optimization algorithms
Optimizer_momentum = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=False, name='Momentum')
Optimizer_nesterov = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=True, name='Nesterov')
Optimizer_adagrad = tf.keras.optimizers.Adagrad(learning_rate=0.001, initial_accumulator_value=0.1, epsilon=1e-10, name='Adagrad')
Optimizer_rmsprop = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9, momentum=0.0, epsilon=1e-10, centered=False, name='RMSprop')
Optimizer_adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-10, amsgrad=False, name='Adam')

# %%
# input_size = len(train_dataset.keys())
output_size = 10
hidden_layer_size = 1000
n_epochs = 100

weights_initializer = keras.initializers.GlorotUniform()
#weights_initializer = tf.random_normal_initializer(mean=0.0, stddev=0.05, seed=None)

#A function that trains and validates the model and returns the MSE (for the purpose of time-constrained comparison of BSG and Mini-SGD)
def train_val_model(run_dir, hparams):
    model = keras.models.Sequential([
            #Layer to be used as an entry point into a Network
            keras.layers.InputLayer(input_shape=[len(train_dataset.keys())]),
            #Dense layer 1
            keras.layers.Dense(hidden_layer_size, activation='relu', 
                               kernel_initializer = weights_initializer,
                               name='Layer_1'),
        
            #Batch Layer
            #keras.layers.BatchNormalization(),
        
            #Dense layer 2
            keras.layers.Dense(hidden_layer_size, activation='relu', 
                               kernel_initializer = weights_initializer,
                               name='Layer_2'),
        
            #Batch Layer
            #keras.layers.BatchNormalization(),
        
            #activation function is linear since we are doing regression
            keras.layers.Dense(output_size, activation='linear', name='Output_layer')
                                ])
    
    #Compiling the model
    model.compile(optimizer=hparams['optimizer'], 
                  loss='mean_squared_error', #Computes the mean of squares of errors between labels and predictions
                  metrics=['mean_squared_error']) #Computes the mean squared error between y_true and y_pred
    
    # initialize TimeStopping callback 
    #time_stopping_callback = tfa.callbacks.TimeStopping(seconds=5*60, verbose=1)
    
    #Training the network
    history = model.fit(normed_train_data, train_labels, 
         epochs=n_epochs,
         batch_size=256, 
         verbose=2,
         #validation_split=0.2,
         callbacks=[tf.keras.callbacks.TensorBoard(run_dir + "/Heston", update_freq='batch')])
    
    return history

# %%
train_val_model("logs/momentum", {'optimizer': Optimizer_momentum})
train_val_model("logs/nesterov", {'optimizer': Optimizer_nesterov})
train_val_model("logs/adagrad", {'optimizer': Optimizer_adagrad})
train_val_model("logs/rmsprop", {'optimizer': Optimizer_rmsprop})
train_val_model("logs/adam", {'optimizer': Optimizer_adam})
# Out:
# Epoch 1/100
# 352/352 - 13s - loss: 0.0570 - mean_squared_error: 0.0570
# Epoch 2/100
# 352/352 - 13s - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 3/100
# 352/352 - 13s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 4/100
# 352/352 - 13s - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 5/100
# 352/352 - 9s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 6/100
# 352/352 - 9s - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 7/100
# 352/352 - 9s - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 8/100
# 352/352 - 8s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 9/100
# 352/352 - 7s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 10/100
# 352/352 - 8s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 11/100
# 352/352 - 8s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 12/100
# 352/352 - 8s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 13/100
# 352/352 - 8s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 14/100
# 352/352 - 7s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 15/100
# 352/352 - 7s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 16/100
# 352/352 - 7s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 17/100
# 352/352 - 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 18/100
# 352/352 - 8s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 19/100
# 352/352 - 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 20/100
# 352/352 - 8s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 21/100
# 352/352 - 7s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 22/100
# 352/352 - 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 23/100
# 352/352 - 8s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 24/100
# 352/352 - 8s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 25/100
# 352/352 - 8s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 26/100
# 352/352 - 7s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 27/100
# 352/352 - 8s - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 28/100
# 352/352 - 8s - loss: 9.5691e-04 - mean_squared_error: 9.5691e-04
# Epoch 29/100
# 352/352 - 7s - loss: 9.0712e-04 - mean_squared_error: 9.0712e-04
# Epoch 30/100
# 352/352 - 8s - loss: 8.6072e-04 - mean_squared_error: 8.6072e-04
# Epoch 31/100
# 352/352 - 8s - loss: 8.1757e-04 - mean_squared_error: 8.1757e-04
# Epoch 32/100
# 352/352 - 8s - loss: 7.7739e-04 - mean_squared_error: 7.7739e-04
# Epoch 33/100
# 352/352 - 8s - loss: 7.3996e-04 - mean_squared_error: 7.3996e-04
# Epoch 34/100
# 352/352 - 8s - loss: 7.0517e-04 - mean_squared_error: 7.0517e-04
# Epoch 35/100
# 352/352 - 8s - loss: 6.7274e-04 - mean_squared_error: 6.7274e-04
# Epoch 36/100
# 352/352 - 8s - loss: 6.4254e-04 - mean_squared_error: 6.4254e-04
# Epoch 37/100
# 352/352 - 7s - loss: 6.1442e-04 - mean_squared_error: 6.1442e-04
# Epoch 38/100
# 352/352 - 7s - loss: 5.8824e-04 - mean_squared_error: 5.8824e-04
# Epoch 39/100
# 352/352 - 7s - loss: 5.6384e-04 - mean_squared_error: 5.6384e-04
# Epoch 40/100
# 352/352 - 7s - loss: 5.4112e-04 - mean_squared_error: 5.4112e-04
# Epoch 41/100
# 352/352 - 8s - loss: 5.1995e-04 - mean_squared_error: 5.1995e-04
# Epoch 42/100
# 352/352 - 7s - loss: 5.0023e-04 - mean_squared_error: 5.0023e-04
# Epoch 43/100
# 352/352 - 7s - loss: 4.8184e-04 - mean_squared_error: 4.8184e-04
# Epoch 44/100
# 352/352 - 9s - loss: 4.6471e-04 - mean_squared_error: 4.6471e-04
# Epoch 45/100
# 352/352 - 10s - loss: 4.4873e-04 - mean_squared_error: 4.4873e-04
# Epoch 46/100
# 352/352 - 9s - loss: 4.3385e-04 - mean_squared_error: 4.3385e-04
# Epoch 47/100
# 352/352 - 7s - loss: 4.1994e-04 - mean_squared_error: 4.1994e-04
# Epoch 48/100
# 352/352 - 7s - loss: 4.0697e-04 - mean_squared_error: 4.0697e-04
# Epoch 49/100
# 352/352 - 7s - loss: 3.9488e-04 - mean_squared_error: 3.9488e-04
# Epoch 50/100
# 352/352 - 8s - loss: 3.8357e-04 - mean_squared_error: 3.8357e-04
# Epoch 51/100
# 352/352 - 9s - loss: 3.7301e-04 - mean_squared_error: 3.7301e-04
# Epoch 52/100
# 352/352 - 7s - loss: 3.6314e-04 - mean_squared_error: 3.6314e-04
# Epoch 53/100
# 352/352 - 9s - loss: 3.5390e-04 - mean_squared_error: 3.5390e-04
# Epoch 54/100
# 352/352 - 7s - loss: 3.4526e-04 - mean_squared_error: 3.4526e-04
# Epoch 55/100
# 352/352 - 7s - loss: 3.3717e-04 - mean_squared_error: 3.3717e-04
# Epoch 56/100
# 352/352 - 8s - loss: 3.2959e-04 - mean_squared_error: 3.2959e-04
# Epoch 57/100
# 352/352 - 8s - loss: 3.2247e-04 - mean_squared_error: 3.2247e-04
# Epoch 58/100
# 352/352 - 7s - loss: 3.1580e-04 - mean_squared_error: 3.1580e-04
# Epoch 59/100
# 352/352 - 7s - loss: 3.0954e-04 - mean_squared_error: 3.0954e-04
# Epoch 60/100
# 352/352 - 7s - loss: 3.0366e-04 - mean_squared_error: 3.0366e-04
# Epoch 61/100
# 352/352 - 7s - loss: 2.9812e-04 - mean_squared_error: 2.9812e-04
# Epoch 62/100
# 352/352 - 7s - loss: 2.9289e-04 - mean_squared_error: 2.9289e-04
# Epoch 63/100
# 352/352 - 7s - loss: 2.8798e-04 - mean_squared_error: 2.8798e-04
# Epoch 64/100
# 352/352 - 7s - loss: 2.8335e-04 - mean_squared_error: 2.8335e-04
# Epoch 65/100
# 352/352 - 7s - loss: 2.7896e-04 - mean_squared_error: 2.7896e-04
# Epoch 66/100
# 352/352 - 7s - loss: 2.7482e-04 - mean_squared_error: 2.7482e-04
# Epoch 67/100
# 352/352 - 7s - loss: 2.7090e-04 - mean_squared_error: 2.7090e-04
# Epoch 68/100
# 352/352 - 7s - loss: 2.6718e-04 - mean_squared_error: 2.6718e-04
# Epoch 69/100
# 352/352 - 7s - loss: 2.6366e-04 - mean_squared_error: 2.6366e-04
# Epoch 70/100
# 352/352 - 7s - loss: 2.6031e-04 - mean_squared_error: 2.6031e-04
# Epoch 71/100
# 352/352 - 9s - loss: 2.5713e-04 - mean_squared_error: 2.5713e-04
# Epoch 72/100
# 352/352 - 8s - loss: 2.5410e-04 - mean_squared_error: 2.5410e-04
# Epoch 73/100
# 352/352 - 9s - loss: 2.5121e-04 - mean_squared_error: 2.5121e-04
# Epoch 74/100
# 352/352 - 8s - loss: 2.4845e-04 - mean_squared_error: 2.4845e-04
# Epoch 75/100
# 352/352 - 8s - loss: 2.4582e-04 - mean_squared_error: 2.4582e-04
# Epoch 76/100
# 352/352 - 8s - loss: 2.4329e-04 - mean_squared_error: 2.4329e-04
# Epoch 77/100
# 352/352 - 10s - loss: 2.4088e-04 - mean_squared_error: 2.4088e-04
# Epoch 78/100
# 352/352 - 16s - loss: 2.3857e-04 - mean_squared_error: 2.3857e-04
# Epoch 79/100
# 352/352 - 13s - loss: 2.3635e-04 - mean_squared_error: 2.3635e-04
# Epoch 80/100
# 352/352 - 13s - loss: 2.3422e-04 - mean_squared_error: 2.3422e-04
# Epoch 81/100
# 352/352 - 12s - loss: 2.3215e-04 - mean_squared_error: 2.3215e-04
# Epoch 82/100
# 352/352 - 14s - loss: 2.3018e-04 - mean_squared_error: 2.3018e-04
# Epoch 83/100
# 352/352 - 8s - loss: 2.2826e-04 - mean_squared_error: 2.2826e-04
# Epoch 84/100
# 352/352 - 8s - loss: 2.2642e-04 - mean_squared_error: 2.2642e-04
# Epoch 85/100
# 352/352 - 8s - loss: 2.2464e-04 - mean_squared_error: 2.2464e-04
# Epoch 86/100
# 352/352 - 8s - loss: 2.2291e-04 - mean_squared_error: 2.2291e-04
# Epoch 87/100
# 352/352 - 8s - loss: 2.2124e-04 - mean_squared_error: 2.2124e-04
# Epoch 88/100
# 352/352 - 8s - loss: 2.1962e-04 - mean_squared_error: 2.1962e-04
# Epoch 89/100
# 352/352 - 8s - loss: 2.1805e-04 - mean_squared_error: 2.1805e-04
# Epoch 90/100
# 352/352 - 8s - loss: 2.1652e-04 - mean_squared_error: 2.1652e-04
# Epoch 91/100
# 352/352 - 7s - loss: 2.1503e-04 - mean_squared_error: 2.1503e-04
# Epoch 92/100
# 352/352 - 7s - loss: 2.1359e-04 - mean_squared_error: 2.1359e-04
# Epoch 93/100
# 352/352 - 7s - loss: 2.1218e-04 - mean_squared_error: 2.1218e-04
# Epoch 94/100
# 352/352 - 7s - loss: 2.1080e-04 - mean_squared_error: 2.1080e-04
# Epoch 95/100
# 352/352 - 8s - loss: 2.0946e-04 - mean_squared_error: 2.0946e-04
# Epoch 96/100
# 352/352 - 7s - loss: 2.0816e-04 - mean_squared_error: 2.0816e-04
# Epoch 97/100
# 352/352 - 7s - loss: 2.0688e-04 - mean_squared_error: 2.0688e-04
# Epoch 98/100
# 352/352 - 7s - loss: 2.0563e-04 - mean_squared_error: 2.0563e-04
# Epoch 99/100
# 352/352 - 7s - loss: 2.0441e-04 - mean_squared_error: 2.0441e-04
# Epoch 100/100
# 352/352 - 7s - loss: 2.0322e-04 - mean_squared_error: 2.0322e-04
# Epoch 1/100
# 352/352 - 8s - loss: 0.0573 - mean_squared_error: 0.0573
# Epoch 2/100
# 352/352 - 8s - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 3/100
# 352/352 - 7s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 4/100
# 352/352 - 7s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 5/100
# 352/352 - 8s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 6/100
# 352/352 - 8s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 7/100
# 352/352 - 7s - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 8/100
# 352/352 - 9s - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 9/100
# 352/352 - 8s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 10/100
# 352/352 - 8s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 11/100
# 352/352 - 8s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 12/100
# 352/352 - 8s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 13/100
# 352/352 - 10s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 14/100
# 352/352 - 10s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 15/100
# 352/352 - 8s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 16/100
# 352/352 - 8s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 17/100
# 352/352 - 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 18/100
# 352/352 - 8s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 19/100
# 352/352 - 8s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 20/100
# 352/352 - 8s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 21/100
# 352/352 - 8s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 22/100
# 352/352 - 8s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 23/100
# 352/352 - 8s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 24/100
# 352/352 - 8s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 25/100
# 352/352 - 7s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 26/100
# 352/352 - 7s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 27/100
# 352/352 - 8s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 28/100
# 352/352 - 11s - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 29/100
# 352/352 - 17s - loss: 9.5534e-04 - mean_squared_error: 9.5534e-04
# Epoch 30/100
# 352/352 - 12s - loss: 9.0697e-04 - mean_squared_error: 9.0697e-04
# Epoch 31/100
# 352/352 - 9s - loss: 8.6175e-04 - mean_squared_error: 8.6175e-04
# Epoch 32/100
# 352/352 - 10s - loss: 8.1952e-04 - mean_squared_error: 8.1952e-04
# Epoch 33/100
# 352/352 - 12s - loss: 7.8006e-04 - mean_squared_error: 7.8006e-04
# Epoch 34/100
# 352/352 - 15s - loss: 7.4317e-04 - mean_squared_error: 7.4317e-04
# Epoch 35/100
# 352/352 - 12s - loss: 7.0869e-04 - mean_squared_error: 7.0869e-04
# Epoch 36/100
# 352/352 - 12s - loss: 6.7647e-04 - mean_squared_error: 6.7647e-04
# Epoch 37/100
# 352/352 - 13s - loss: 6.4637e-04 - mean_squared_error: 6.4637e-04
# Epoch 38/100
# 352/352 - 8s - loss: 6.1824e-04 - mean_squared_error: 6.1824e-04
# Epoch 39/100
# 352/352 - 7s - loss: 5.9194e-04 - mean_squared_error: 5.9194e-04
# Epoch 40/100
# 352/352 - 7s - loss: 5.6737e-04 - mean_squared_error: 5.6737e-04
# Epoch 41/100
# 352/352 - 7s - loss: 5.4440e-04 - mean_squared_error: 5.4440e-04
# Epoch 42/100
# 352/352 - 7s - loss: 5.2295e-04 - mean_squared_error: 5.2295e-04
# Epoch 43/100
# 352/352 - 8s - loss: 5.0288e-04 - mean_squared_error: 5.0288e-04
# Epoch 44/100
# 352/352 - 10s - loss: 4.8413e-04 - mean_squared_error: 4.8413e-04
# Epoch 45/100
# 352/352 - 10s - loss: 4.6661e-04 - mean_squared_error: 4.6661e-04
# Epoch 46/100
# 352/352 - 8s - loss: 4.5021e-04 - mean_squared_error: 4.5021e-04
# Epoch 47/100
# 352/352 - 7s - loss: 4.3490e-04 - mean_squared_error: 4.3490e-04
# Epoch 48/100
# 352/352 - 8s - loss: 4.2058e-04 - mean_squared_error: 4.2058e-04
# Epoch 49/100
# 352/352 - 10s - loss: 4.0717e-04 - mean_squared_error: 4.0717e-04
# Epoch 50/100
# 352/352 - 10s - loss: 3.9464e-04 - mean_squared_error: 3.9464e-04
# Epoch 51/100
# 352/352 - 9s - loss: 3.8290e-04 - mean_squared_error: 3.8290e-04
# Epoch 52/100
# 352/352 - 7s - loss: 3.7194e-04 - mean_squared_error: 3.7194e-04
# Epoch 53/100
# 352/352 - 8s - loss: 3.6165e-04 - mean_squared_error: 3.6165e-04
# Epoch 54/100
# 352/352 - 8s - loss: 3.5203e-04 - mean_squared_error: 3.5203e-04
# Epoch 55/100
# 352/352 - 8s - loss: 3.4300e-04 - mean_squared_error: 3.4300e-04
# Epoch 56/100
# 352/352 - 8s - loss: 3.3454e-04 - mean_squared_error: 3.3454e-04
# Epoch 57/100
# 352/352 - 8s - loss: 3.2660e-04 - mean_squared_error: 3.2660e-04
# Epoch 58/100
# 352/352 - 10s - loss: 3.1916e-04 - mean_squared_error: 3.1916e-04
# Epoch 59/100
# 352/352 - 10s - loss: 3.1217e-04 - mean_squared_error: 3.1217e-04
# Epoch 60/100
# 352/352 - 8s - loss: 3.0559e-04 - mean_squared_error: 3.0559e-04
# Epoch 61/100
# 352/352 - 8s - loss: 2.9942e-04 - mean_squared_error: 2.9942e-04
# Epoch 62/100
# 352/352 - 11s - loss: 2.9361e-04 - mean_squared_error: 2.9361e-04
# Epoch 63/100
# 352/352 - 12s - loss: 2.8814e-04 - mean_squared_error: 2.8814e-04
# Epoch 64/100
# 352/352 - 10s - loss: 2.8298e-04 - mean_squared_error: 2.8298e-04
# Epoch 65/100
# 352/352 - 10s - loss: 2.7812e-04 - mean_squared_error: 2.7812e-04
# Epoch 66/100
# 352/352 - 12s - loss: 2.7353e-04 - mean_squared_error: 2.7353e-04
# Epoch 67/100
# 352/352 - 12s - loss: 2.6919e-04 - mean_squared_error: 2.6919e-04
# Epoch 68/100
# 352/352 - 8s - loss: 2.6510e-04 - mean_squared_error: 2.6510e-04
# Epoch 69/100
# 352/352 - 7s - loss: 2.6122e-04 - mean_squared_error: 2.6122e-04
# Epoch 70/100
# 352/352 - 7s - loss: 2.5754e-04 - mean_squared_error: 2.5754e-04
# Epoch 71/100
# 352/352 - 11s - loss: 2.5406e-04 - mean_squared_error: 2.5406e-04
# Epoch 72/100
# 352/352 - 9s - loss: 2.5075e-04 - mean_squared_error: 2.5075e-04
# Epoch 73/100
# 352/352 - 7s - loss: 2.4761e-04 - mean_squared_error: 2.4761e-04
# Epoch 74/100
# 352/352 - 7s - loss: 2.4461e-04 - mean_squared_error: 2.4461e-04
# Epoch 75/100
# 352/352 - 8s - loss: 2.4177e-04 - mean_squared_error: 2.4177e-04
# Epoch 76/100
# 352/352 - 7s - loss: 2.3905e-04 - mean_squared_error: 2.3905e-04
# Epoch 77/100
# 352/352 - 7s - loss: 2.3646e-04 - mean_squared_error: 2.3646e-04
# Epoch 78/100
# 352/352 - 11s - loss: 2.3398e-04 - mean_squared_error: 2.3398e-04
# Epoch 79/100
# 352/352 - 8s - loss: 2.3161e-04 - mean_squared_error: 2.3161e-04
# Epoch 80/100
# 352/352 - 7s - loss: 2.2934e-04 - mean_squared_error: 2.2934e-04
# Epoch 81/100
# 352/352 - 7s - loss: 2.2716e-04 - mean_squared_error: 2.2716e-04
# Epoch 82/100
# 352/352 - 8s - loss: 2.2507e-04 - mean_squared_error: 2.2507e-04
# Epoch 83/100
# 352/352 - 8s - loss: 2.2307e-04 - mean_squared_error: 2.2307e-04
# Epoch 84/100
# 352/352 - 8s - loss: 2.2114e-04 - mean_squared_error: 2.2114e-04
# Epoch 85/100
# 352/352 - 8s - loss: 2.1927e-04 - mean_squared_error: 2.1927e-04
# Epoch 86/100
# 352/352 - 7s - loss: 2.1748e-04 - mean_squared_error: 2.1748e-04
# Epoch 87/100
# 352/352 - 7s - loss: 2.1576e-04 - mean_squared_error: 2.1576e-04
# Epoch 88/100
# 352/352 - 7s - loss: 2.1408e-04 - mean_squared_error: 2.1408e-04
# Epoch 89/100
# 352/352 - 7s - loss: 2.1246e-04 - mean_squared_error: 2.1246e-04
# Epoch 90/100
# 352/352 - 8s - loss: 2.1090e-04 - mean_squared_error: 2.1090e-04
# Epoch 91/100
# 352/352 - 8s - loss: 2.0938e-04 - mean_squared_error: 2.0938e-04
# Epoch 92/100
# 352/352 - 9s - loss: 2.0791e-04 - mean_squared_error: 2.0791e-04
# Epoch 93/100
# 352/352 - 10s - loss: 2.0648e-04 - mean_squared_error: 2.0648e-04
# Epoch 94/100
# 352/352 - 7s - loss: 2.0509e-04 - mean_squared_error: 2.0509e-04
# Epoch 95/100
# 352/352 - 7s - loss: 2.0374e-04 - mean_squared_error: 2.0374e-04
# Epoch 96/100
# 352/352 - 7s - loss: 2.0243e-04 - mean_squared_error: 2.0243e-04
# Epoch 97/100
# 352/352 - 8s - loss: 2.0115e-04 - mean_squared_error: 2.0115e-04
# Epoch 98/100
# 352/352 - 7s - loss: 1.9990e-04 - mean_squared_error: 1.9990e-04
# Epoch 99/100
# 352/352 - 7s - loss: 1.9868e-04 - mean_squared_error: 1.9868e-04
# Epoch 100/100
# 352/352 - 7s - loss: 1.9749e-04 - mean_squared_error: 1.9749e-04
# Epoch 1/100
# 352/352 - 8s - loss: 0.1177 - mean_squared_error: 0.1177
# Epoch 2/100
# 352/352 - 7s - loss: 0.0194 - mean_squared_error: 0.0194
# Epoch 3/100
# 352/352 - 7s - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 4/100
# 352/352 - 8s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 5/100
# 352/352 - 8s - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 6/100
# 352/352 - 7s - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 7/100
# 352/352 - 8s - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 8/100
# 352/352 - 8s - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 9/100
# 352/352 - 8s - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 10/100
# 352/352 - 9s - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 11/100
# 352/352 - 9s - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 12/100
# 352/352 - 9s - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 13/100
# 352/352 - 10s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 14/100
# 352/352 - 8s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 15/100
# 352/352 - 8s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 16/100
# 352/352 - 8s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 17/100
# 352/352 - 8s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 18/100
# 352/352 - 7s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 19/100
# 352/352 - 8s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 20/100
# 352/352 - 13s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 21/100
# 352/352 - 9s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 22/100
# 352/352 - 8s - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 23/100
# 352/352 - 8s - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 24/100
# 352/352 - 10s - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 25/100
# 352/352 - 10s - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 26/100
# 352/352 - 8s - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 27/100
# 352/352 - 8s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 28/100
# 352/352 - 8s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 29/100
# 352/352 - 9s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 30/100
# 352/352 - 8s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 31/100
# 352/352 - 8s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 32/100
# 352/352 - 12s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 33/100
# 352/352 - 11s - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 34/100
# 352/352 - 9s - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 35/100
# 352/352 - 8s - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 36/100
# 352/352 - 9s - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 37/100
# 352/352 - 9s - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 38/100
# 352/352 - 10s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 39/100
# 352/352 - 8s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 40/100
# 352/352 - 9s - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 41/100
# 352/352 - 8s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 42/100
# 352/352 - 9s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 43/100
# 352/352 - 8s - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 44/100
# 352/352 - 9s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 45/100
# 352/352 - 8s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 46/100
# 352/352 - 10s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 47/100
# 352/352 - 10s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 48/100
# 352/352 - 9s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 49/100
# 352/352 - 8s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 50/100
# 352/352 - 9s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 51/100
# 352/352 - 9s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 52/100
# 352/352 - 10s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 53/100
# 352/352 - 11s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 54/100
# 352/352 - 9s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 55/100
# 352/352 - 8s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 56/100
# 352/352 - 8s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 57/100
# 352/352 - 10s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 58/100
# 352/352 - 10s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 59/100
# 352/352 - 9s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 60/100
# 352/352 - 8s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 61/100
# 352/352 - 8s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 62/100
# 352/352 - 8s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 63/100
# 352/352 - 9s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 64/100
# 352/352 - 10s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 65/100
# 352/352 - 9s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 66/100
# 352/352 - 8s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 67/100
# 352/352 - 8s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 68/100
# 352/352 - 8s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 69/100
# 352/352 - 10s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 70/100
# 352/352 - 9s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 71/100
# 352/352 - 8s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 72/100
# 352/352 - 14s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 73/100
# 352/352 - 14s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 74/100
# 352/352 - 12s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 75/100
# 352/352 - 11s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 76/100
# 352/352 - 10s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 77/100
# 352/352 - 9s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 78/100
# 352/352 - 8s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 79/100
# 352/352 - 9s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 80/100
# 352/352 - 11s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 81/100
# 352/352 - 11s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 82/100
# 352/352 - 8s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 83/100
# 352/352 - 8s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 84/100
# 352/352 - 8s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 85/100
# 352/352 - 9s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 86/100
# 352/352 - 8s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 87/100
# 352/352 - 10s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 88/100
# 352/352 - 10s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 89/100
# 352/352 - 9s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 90/100
# 352/352 - 8s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 91/100
# 352/352 - 8s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 92/100
# 352/352 - 8s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 93/100
# 352/352 - 8s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 94/100
# 352/352 - 8s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 95/100
# 352/352 - 8s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 96/100
# 352/352 - 8s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 97/100
# 352/352 - 8s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 98/100
# 352/352 - 8s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 99/100
# 352/352 - 9s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 100/100
# 352/352 - 8s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 1/100
# 352/352 - 11s - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 2/100
# 352/352 - 12s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 3/100
# 352/352 - 12s - loss: 9.4463e-04 - mean_squared_error: 9.4463e-04
# Epoch 4/100
# 352/352 - 10s - loss: 6.5961e-04 - mean_squared_error: 6.5961e-04
# Epoch 5/100
# 352/352 - 10s - loss: 5.2183e-04 - mean_squared_error: 5.2183e-04
# Epoch 6/100
# 352/352 - 10s - loss: 4.4692e-04 - mean_squared_error: 4.4692e-04
# Epoch 7/100
# 352/352 - 11s - loss: 3.8037e-04 - mean_squared_error: 3.8037e-04
# Epoch 8/100
# 352/352 - 10s - loss: 3.2918e-04 - mean_squared_error: 3.2918e-04
# Epoch 9/100
# 352/352 - 11s - loss: 2.8619e-04 - mean_squared_error: 2.8619e-04
# Epoch 10/100
# 352/352 - 12s - loss: 2.5293e-04 - mean_squared_error: 2.5293e-04
# Epoch 11/100
# 352/352 - 12s - loss: 2.2467e-04 - mean_squared_error: 2.2467e-04
# Epoch 12/100
# 352/352 - 10s - loss: 2.0298e-04 - mean_squared_error: 2.0298e-04
# Epoch 13/100
# 352/352 - 10s - loss: 1.7897e-04 - mean_squared_error: 1.7897e-04
# Epoch 14/100
# 352/352 - 10s - loss: 1.6286e-04 - mean_squared_error: 1.6286e-04
# Epoch 15/100
# 352/352 - 10s - loss: 1.4689e-04 - mean_squared_error: 1.4689e-04
# Epoch 16/100
# 352/352 - 10s - loss: 1.3640e-04 - mean_squared_error: 1.3640e-04
# Epoch 17/100
# 352/352 - 10s - loss: 1.2700e-04 - mean_squared_error: 1.2700e-04
# Epoch 18/100
# 352/352 - 10s - loss: 1.1840e-04 - mean_squared_error: 1.1840e-04
# Epoch 19/100
# 352/352 - 10s - loss: 1.1028e-04 - mean_squared_error: 1.1028e-04
# Epoch 20/100
# 352/352 - 10s - loss: 1.0370e-04 - mean_squared_error: 1.0370e-04
# Epoch 21/100
# 352/352 - 11s - loss: 9.6852e-05 - mean_squared_error: 9.6852e-05
# Epoch 22/100
# 352/352 - 10s - loss: 9.1057e-05 - mean_squared_error: 9.1057e-05
# Epoch 23/100
# 352/352 - 10s - loss: 8.5884e-05 - mean_squared_error: 8.5884e-05
# Epoch 24/100
# 352/352 - 10s - loss: 8.0643e-05 - mean_squared_error: 8.0643e-05
# Epoch 25/100
# 352/352 - 9s - loss: 7.6712e-05 - mean_squared_error: 7.6712e-05
# Epoch 26/100
# 352/352 - 10s - loss: 7.2448e-05 - mean_squared_error: 7.2448e-05
# Epoch 27/100
# 352/352 - 10s - loss: 6.8518e-05 - mean_squared_error: 6.8518e-05
# Epoch 28/100
# 352/352 - 9s - loss: 6.5120e-05 - mean_squared_error: 6.5120e-05
# Epoch 29/100
# 352/352 - 11s - loss: 6.1393e-05 - mean_squared_error: 6.1393e-05
# Epoch 30/100
# 352/352 - 10s - loss: 5.8673e-05 - mean_squared_error: 5.8673e-05
# Epoch 31/100
# 352/352 - 16s - loss: 5.5868e-05 - mean_squared_error: 5.5868e-05
# Epoch 32/100
# 352/352 - 13s - loss: 5.3298e-05 - mean_squared_error: 5.3298e-05
# Epoch 33/100
# 352/352 - 10s - loss: 5.1261e-05 - mean_squared_error: 5.1261e-05
# Epoch 34/100
# 352/352 - 11s - loss: 4.9215e-05 - mean_squared_error: 4.9215e-05
# Epoch 35/100
# 352/352 - 11s - loss: 4.7131e-05 - mean_squared_error: 4.7131e-05
# Epoch 36/100
# 352/352 - 10s - loss: 4.5453e-05 - mean_squared_error: 4.5453e-05
# Epoch 37/100
# 352/352 - 11s - loss: 4.3510e-05 - mean_squared_error: 4.3510e-05
# Epoch 38/100
# 352/352 - 12s - loss: 4.2144e-05 - mean_squared_error: 4.2144e-05
# Epoch 39/100
# 352/352 - 11s - loss: 4.0531e-05 - mean_squared_error: 4.0531e-05
# Epoch 40/100
# 352/352 - 10s - loss: 3.8786e-05 - mean_squared_error: 3.8786e-05
# Epoch 41/100
# 352/352 - 10s - loss: 3.7558e-05 - mean_squared_error: 3.7558e-05
# Epoch 42/100
# 352/352 - 11s - loss: 3.6506e-05 - mean_squared_error: 3.6506e-05
# Epoch 43/100
# 352/352 - 12s - loss: 3.5630e-05 - mean_squared_error: 3.5630e-05
# Epoch 44/100
# 352/352 - 11s - loss: 3.4591e-05 - mean_squared_error: 3.4591e-05
# Epoch 45/100
# 352/352 - 11s - loss: 3.3463e-05 - mean_squared_error: 3.3463e-05
# Epoch 46/100
# 352/352 - 11s - loss: 3.2884e-05 - mean_squared_error: 3.2884e-05
# Epoch 47/100
# 352/352 - 11s - loss: 3.2418e-05 - mean_squared_error: 3.2418e-05
# Epoch 48/100
# 352/352 - 14s - loss: 3.1516e-05 - mean_squared_error: 3.1516e-05
# Epoch 49/100
# 352/352 - 13s - loss: 3.0680e-05 - mean_squared_error: 3.0680e-05
# Epoch 50/100
# 352/352 - 10s - loss: 2.9703e-05 - mean_squared_error: 2.9703e-05
# Epoch 51/100
# 352/352 - 9s - loss: 2.9023e-05 - mean_squared_error: 2.9023e-05
# Epoch 52/100
# 352/352 - 10s - loss: 2.8463e-05 - mean_squared_error: 2.8463e-05
# Epoch 53/100
# 352/352 - 11s - loss: 2.7380e-05 - mean_squared_error: 2.7380e-05
# Epoch 54/100
# 352/352 - 12s - loss: 2.6679e-05 - mean_squared_error: 2.6679e-05
# Epoch 55/100
# 352/352 - 13s - loss: 2.5712e-05 - mean_squared_error: 2.5712e-05
# Epoch 56/100
# 352/352 - 12s - loss: 2.4973e-05 - mean_squared_error: 2.4973e-05
# Epoch 57/100
# 352/352 - 10s - loss: 2.4435e-05 - mean_squared_error: 2.4435e-05
# Epoch 58/100
# 352/352 - 10s - loss: 2.3958e-05 - mean_squared_error: 2.3958e-05
# Epoch 59/100
# 352/352 - 10s - loss: 2.3375e-05 - mean_squared_error: 2.3375e-05
# Epoch 60/100
# 352/352 - 12s - loss: 2.2729e-05 - mean_squared_error: 2.2729e-05
# Epoch 61/100
# 352/352 - 10s - loss: 2.2345e-05 - mean_squared_error: 2.2345e-05
# Epoch 62/100
# 352/352 - 11s - loss: 2.1767e-05 - mean_squared_error: 2.1767e-05
# Epoch 63/100
# 352/352 - 11s - loss: 2.1172e-05 - mean_squared_error: 2.1172e-05
# Epoch 64/100
# 352/352 - 9s - loss: 2.0810e-05 - mean_squared_error: 2.0810e-05
# Epoch 65/100
# 352/352 - 10s - loss: 2.0396e-05 - mean_squared_error: 2.0396e-05
# Epoch 66/100
# 352/352 - 13s - loss: 2.0005e-05 - mean_squared_error: 2.0005e-05
# Epoch 67/100
# 352/352 - 11s - loss: 1.9746e-05 - mean_squared_error: 1.9746e-05
# Epoch 68/100
# 352/352 - 10s - loss: 1.9292e-05 - mean_squared_error: 1.9292e-05
# Epoch 69/100
# 352/352 - 10s - loss: 1.9053e-05 - mean_squared_error: 1.9053e-05
# Epoch 70/100
# 352/352 - 10s - loss: 1.8653e-05 - mean_squared_error: 1.8653e-05
# Epoch 71/100
# 352/352 - 11s - loss: 1.8410e-05 - mean_squared_error: 1.8410e-05
# Epoch 72/100
# 352/352 - 15s - loss: 1.8118e-05 - mean_squared_error: 1.8118e-05
# Epoch 73/100
# 352/352 - 18s - loss: 1.7910e-05 - mean_squared_error: 1.7910e-05
# Epoch 74/100
# 352/352 - 14s - loss: 1.7694e-05 - mean_squared_error: 1.7694e-05
# Epoch 75/100
# 352/352 - 17s - loss: 1.7183e-05 - mean_squared_error: 1.7183e-05
# Epoch 76/100
# 352/352 - 16s - loss: 1.6929e-05 - mean_squared_error: 1.6929e-05
# Epoch 77/100
# 352/352 - 15s - loss: 1.6788e-05 - mean_squared_error: 1.6788e-05
# Epoch 78/100
# 352/352 - 15s - loss: 1.6322e-05 - mean_squared_error: 1.6322e-05
# Epoch 79/100
# 352/352 - 11s - loss: 1.6257e-05 - mean_squared_error: 1.6257e-05
# Epoch 80/100
# 352/352 - 11s - loss: 1.5943e-05 - mean_squared_error: 1.5943e-05
# Epoch 81/100
# 352/352 - 10s - loss: 1.5556e-05 - mean_squared_error: 1.5556e-05
# Epoch 82/100
# 352/352 - 9s - loss: 1.5243e-05 - mean_squared_error: 1.5243e-05
# Epoch 83/100
# 352/352 - 10s - loss: 1.4960e-05 - mean_squared_error: 1.4960e-05
# Epoch 84/100
# 352/352 - 10s - loss: 1.4596e-05 - mean_squared_error: 1.4596e-05
# Epoch 85/100
# 352/352 - 10s - loss: 1.4528e-05 - mean_squared_error: 1.4528e-05
# Epoch 86/100
# 352/352 - 9s - loss: 1.4235e-05 - mean_squared_error: 1.4235e-05
# Epoch 87/100
# 352/352 - 10s - loss: 1.3912e-05 - mean_squared_error: 1.3912e-05
# Epoch 88/100
# 352/352 - 11s - loss: 1.3896e-05 - mean_squared_error: 1.3896e-05
# Epoch 89/100
# 352/352 - 11s - loss: 1.3529e-05 - mean_squared_error: 1.3529e-05
# Epoch 90/100
# 352/352 - 10s - loss: 1.3398e-05 - mean_squared_error: 1.3398e-05
# Epoch 91/100
# 352/352 - 10s - loss: 1.3293e-05 - mean_squared_error: 1.3293e-05
# Epoch 92/100
# 352/352 - 12s - loss: 1.3170e-05 - mean_squared_error: 1.3170e-05
# Epoch 93/100
# 352/352 - 13s - loss: 1.2906e-05 - mean_squared_error: 1.2906e-05
# Epoch 94/100
# 352/352 - 9s - loss: 1.2922e-05 - mean_squared_error: 1.2922e-05
# Epoch 95/100
# 352/352 - 16s - loss: 1.2752e-05 - mean_squared_error: 1.2752e-05
# Epoch 96/100
# 352/352 - 17s - loss: 1.2676e-05 - mean_squared_error: 1.2676e-05
# Epoch 97/100
# 352/352 - 17s - loss: 1.2434e-05 - mean_squared_error: 1.2434e-05
# Epoch 98/100
# 352/352 - 16s - loss: 1.2399e-05 - mean_squared_error: 1.2399e-05
# Epoch 99/100
# 352/352 - 12s - loss: 1.2190e-05 - mean_squared_error: 1.2190e-05
# Epoch 100/100
# 352/352 - 14s - loss: 1.2121e-05 - mean_squared_error: 1.2121e-05
# Epoch 1/100
# 352/352 - 14s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 2/100
# 352/352 - 12s - loss: 5.0661e-05 - mean_squared_error: 5.0661e-05
# Epoch 3/100
# 352/352 - 8s - loss: 3.0518e-05 - mean_squared_error: 3.0518e-05
# Epoch 4/100
# 352/352 - 10s - loss: 2.2400e-05 - mean_squared_error: 2.2400e-05
# Epoch 5/100
# 352/352 - 13s - loss: 2.0993e-05 - mean_squared_error: 2.0993e-05
# Epoch 6/100
# 352/352 - 18s - loss: 2.3162e-05 - mean_squared_error: 2.3162e-05
# Epoch 7/100
# 352/352 - 12s - loss: 2.5273e-05 - mean_squared_error: 2.5273e-05
# Epoch 8/100
# 352/352 - 15s - loss: 2.3894e-05 - mean_squared_error: 2.3894e-05
# Epoch 9/100
# 352/352 - 15s - loss: 2.4849e-05 - mean_squared_error: 2.4849e-05
# Epoch 10/100
# 352/352 - 14s - loss: 2.2859e-05 - mean_squared_error: 2.2859e-05
# Epoch 11/100
# 352/352 - 14s - loss: 2.1685e-05 - mean_squared_error: 2.1685e-05
# Epoch 12/100
# 352/352 - 14s - loss: 1.9623e-05 - mean_squared_error: 1.9623e-05
# Epoch 13/100
# 352/352 - 12s - loss: 1.8833e-05 - mean_squared_error: 1.8833e-05
# Epoch 14/100
# 352/352 - 13s - loss: 1.4931e-05 - mean_squared_error: 1.4931e-05
# Epoch 15/100
# 352/352 - 14s - loss: 1.7023e-05 - mean_squared_error: 1.7023e-05
# Epoch 16/100
# 352/352 - 9s - loss: 1.4717e-05 - mean_squared_error: 1.4717e-05
# Epoch 17/100
# 352/352 - 10s - loss: 1.2659e-05 - mean_squared_error: 1.2659e-05
# Epoch 18/100
# 352/352 - 11s - loss: 9.9193e-06 - mean_squared_error: 9.9193e-06
# Epoch 19/100
# 352/352 - 11s - loss: 1.0715e-05 - mean_squared_error: 1.0715e-05
# Epoch 20/100
# 352/352 - 11s - loss: 1.4099e-05 - mean_squared_error: 1.4099e-05
# Epoch 21/100
# 352/352 - 9s - loss: 5.3524e-06 - mean_squared_error: 5.3524e-06
# Epoch 22/100
# 352/352 - 13s - loss: 9.4055e-06 - mean_squared_error: 9.4055e-06
# Epoch 23/100
# 352/352 - 13s - loss: 8.4954e-06 - mean_squared_error: 8.4954e-06
# Epoch 24/100
# 352/352 - 12s - loss: 7.3572e-06 - mean_squared_error: 7.3572e-06
# Epoch 25/100
# 352/352 - 9s - loss: 8.4277e-06 - mean_squared_error: 8.4277e-06
# Epoch 26/100
# 352/352 - 11s - loss: 5.5912e-06 - mean_squared_error: 5.5912e-06
# Epoch 27/100
# 352/352 - 10s - loss: 7.2528e-06 - mean_squared_error: 7.2528e-06
# Epoch 28/100
# 352/352 - 17s - loss: 4.9133e-06 - mean_squared_error: 4.9133e-06
# Epoch 29/100
# 352/352 - 14s - loss: 6.6525e-06 - mean_squared_error: 6.6525e-06
# Epoch 30/100
# 352/352 - 11s - loss: 5.4577e-06 - mean_squared_error: 5.4577e-06
# Epoch 31/100
# 352/352 - 11s - loss: 5.9486e-06 - mean_squared_error: 5.9486e-06
# Epoch 32/100
# 352/352 - 12s - loss: 4.1125e-06 - mean_squared_error: 4.1125e-06
# Epoch 33/100
# 352/352 - 14s - loss: 6.4387e-06 - mean_squared_error: 6.4387e-06
# Epoch 34/100
# 352/352 - 12s - loss: 3.7516e-06 - mean_squared_error: 3.7516e-06
# Epoch 35/100
# 352/352 - 8s - loss: 4.9096e-06 - mean_squared_error: 4.9096e-06
# Epoch 36/100
# 352/352 - 11s - loss: 4.7309e-06 - mean_squared_error: 4.7309e-06
# Epoch 37/100
# 352/352 - 11s - loss: 4.5936e-06 - mean_squared_error: 4.5936e-06
# Epoch 38/100
# 352/352 - 12s - loss: 4.1626e-06 - mean_squared_error: 4.1626e-06
# Epoch 39/100
# 352/352 - 11s - loss: 4.2833e-06 - mean_squared_error: 4.2833e-06
# Epoch 40/100
# 352/352 - 11s - loss: 5.4631e-06 - mean_squared_error: 5.4631e-06
# Epoch 41/100
# 352/352 - 12s - loss: 2.1488e-06 - mean_squared_error: 2.1488e-06
# Epoch 42/100
# 352/352 - 13s - loss: 4.5590e-06 - mean_squared_error: 4.5590e-06
# Epoch 43/100
# 352/352 - 12s - loss: 3.2032e-06 - mean_squared_error: 3.2032e-06
# Epoch 44/100
# 352/352 - 14s - loss: 3.9798e-06 - mean_squared_error: 3.9798e-06
# Epoch 45/100
# 352/352 - 11s - loss: 3.2902e-06 - mean_squared_error: 3.2902e-06
# Epoch 46/100
# 352/352 - 9s - loss: 4.4583e-06 - mean_squared_error: 4.4583e-06
# Epoch 47/100
# 352/352 - 10s - loss: 2.4706e-06 - mean_squared_error: 2.4706e-06
# Epoch 48/100
# 352/352 - 13s - loss: 3.8112e-06 - mean_squared_error: 3.8112e-06
# Epoch 49/100
# 352/352 - 14s - loss: 2.7666e-06 - mean_squared_error: 2.7666e-06
# Epoch 50/100
# 352/352 - 17s - loss: 3.3537e-06 - mean_squared_error: 3.3537e-06
# Epoch 51/100
# 352/352 - 13s - loss: 3.2213e-06 - mean_squared_error: 3.2213e-06
# Epoch 52/100
# 352/352 - 13s - loss: 3.5858e-06 - mean_squared_error: 3.5858e-06
# Epoch 53/100
# 352/352 - 9s - loss: 1.8587e-06 - mean_squared_error: 1.8587e-06
# Epoch 54/100
# 352/352 - 9s - loss: 2.8926e-06 - mean_squared_error: 2.8926e-06
# Epoch 55/100
# 352/352 - 9s - loss: 2.7790e-06 - mean_squared_error: 2.7790e-06
# Epoch 56/100
# 352/352 - 9s - loss: 2.7097e-06 - mean_squared_error: 2.7097e-06
# Epoch 57/100
# 352/352 - 12s - loss: 2.8786e-06 - mean_squared_error: 2.8786e-06
# Epoch 58/100
# 352/352 - 13s - loss: 2.4962e-06 - mean_squared_error: 2.4962e-06
# Epoch 59/100
# 352/352 - 14s - loss: 2.7956e-06 - mean_squared_error: 2.7956e-06
# Epoch 60/100
# 352/352 - 11s - loss: 3.0989e-06 - mean_squared_error: 3.0989e-06
# Epoch 61/100
# 352/352 - 10s - loss: 2.7808e-06 - mean_squared_error: 2.7808e-06
# Epoch 62/100
# 352/352 - 16s - loss: 1.7960e-06 - mean_squared_error: 1.7960e-06
# Epoch 63/100
# 352/352 - 13s - loss: 2.7103e-06 - mean_squared_error: 2.7103e-06
# Epoch 64/100
# 352/352 - 10s - loss: 2.2601e-06 - mean_squared_error: 2.2601e-06
# Epoch 65/100
# 352/352 - 10s - loss: 2.7723e-06 - mean_squared_error: 2.7723e-06
# Epoch 66/100
# 352/352 - 14s - loss: 2.1657e-06 - mean_squared_error: 2.1657e-06
# Epoch 67/100
# 352/352 - 15s - loss: 2.0851e-06 - mean_squared_error: 2.0851e-06
# Epoch 68/100
# 352/352 - 10s - loss: 2.3164e-06 - mean_squared_error: 2.3164e-06
# Epoch 69/100
# 352/352 - 9s - loss: 2.3762e-06 - mean_squared_error: 2.3762e-06
# Epoch 70/100
# 352/352 - 9s - loss: 2.7401e-06 - mean_squared_error: 2.7401e-06
# Epoch 71/100
# 352/352 - 9s - loss: 2.6273e-06 - mean_squared_error: 2.6273e-06
# Epoch 72/100
# 352/352 - 9s - loss: 2.2939e-06 - mean_squared_error: 2.2939e-06
# Epoch 73/100
# 352/352 - 9s - loss: 1.1788e-06 - mean_squared_error: 1.1788e-06
# Epoch 74/100
# 352/352 - 9s - loss: 3.2119e-06 - mean_squared_error: 3.2119e-06
# Epoch 75/100
# 352/352 - 10s - loss: 1.4150e-06 - mean_squared_error: 1.4150e-06
# Epoch 76/100
# 352/352 - 8s - loss: 2.0799e-06 - mean_squared_error: 2.0799e-06
# Epoch 77/100
# 352/352 - 9s - loss: 2.4007e-06 - mean_squared_error: 2.4007e-06
# Epoch 78/100
# 352/352 - 9s - loss: 3.0317e-06 - mean_squared_error: 3.0317e-06
# Epoch 79/100
# 352/352 - 10s - loss: 7.6109e-07 - mean_squared_error: 7.6109e-07
# Epoch 80/100
# 352/352 - 9s - loss: 2.0062e-06 - mean_squared_error: 2.0062e-06
# Epoch 81/100
# 352/352 - 9s - loss: 1.9022e-06 - mean_squared_error: 1.9022e-06
# Epoch 82/100
# 352/352 - 9s - loss: 2.6438e-06 - mean_squared_error: 2.6438e-06
# Epoch 83/100
# 352/352 - 9s - loss: 1.8247e-06 - mean_squared_error: 1.8247e-06
# Epoch 84/100
# 352/352 - 8s - loss: 2.0288e-06 - mean_squared_error: 2.0288e-06
# Epoch 85/100
# 352/352 - 9s - loss: 1.7085e-06 - mean_squared_error: 1.7085e-06
# Epoch 86/100
# 352/352 - 9s - loss: 2.2442e-06 - mean_squared_error: 2.2442e-06
# Epoch 87/100
# 352/352 - 9s - loss: 1.0761e-06 - mean_squared_error: 1.0761e-06
# Epoch 88/100
# 352/352 - 8s - loss: 1.5540e-06 - mean_squared_error: 1.5540e-06
# Epoch 89/100
# 352/352 - 8s - loss: 2.3487e-06 - mean_squared_error: 2.3487e-06
# Epoch 90/100
# 352/352 - 9s - loss: 1.4797e-06 - mean_squared_error: 1.4797e-06
# Epoch 91/100
# 352/352 - 9s - loss: 2.2516e-06 - mean_squared_error: 2.2516e-06
# Epoch 92/100
# 352/352 - 8s - loss: 1.2252e-06 - mean_squared_error: 1.2252e-06
# Epoch 93/100
# 352/352 - 8s - loss: 2.0283e-06 - mean_squared_error: 2.0283e-06
# Epoch 94/100
# 352/352 - 9s - loss: 1.8500e-06 - mean_squared_error: 1.8500e-06
# Epoch 95/100
# 352/352 - 14s - loss: 1.6596e-06 - mean_squared_error: 1.6596e-06
# Epoch 96/100
# 352/352 - 16s - loss: 1.8221e-06 - mean_squared_error: 1.8221e-06
# Epoch 97/100
# 352/352 - 13s - loss: 1.3537e-06 - mean_squared_error: 1.3537e-06
# Epoch 98/100
# 352/352 - 10s - loss: 1.7535e-06 - mean_squared_error: 1.7535e-06
# Epoch 99/100
# 352/352 - 9s - loss: 1.8811e-06 - mean_squared_error: 1.8811e-06
# Epoch 100/100
# 352/352 - 10s - loss: 1.2218e-06 - mean_squared_error: 1.2218e-06

# %%
# %tensorboard --logdir_spec=Momentum:logs/momentum,Nesterov:logs/nesterov,AdaGrad:logs/adagrad,RMSProp:logs/rmsprop,Adam:logs/adam
#%tensorboard --logdir logs/momentum
# Out:
# Reusing TensorBoard on port 6008 (pid 12945), started 1:47:49 ago. (Use '!kill 12945' to kill it.)
#       <iframe id="tensorboard-frame-247494807ef24f5c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-247494807ef24f5c");
#           const url = new URL("/", window.location);
#           url.port = 6008;
#           frame.src = url;
#         })();
#       </script>
